# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriela-Sol/VpC2---Deteccion-de-humo-y-fuego/blob/yolo26/notebooks/02_entrenamiento_YOLO8n_50epochs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 02 - Entrenamiento de modelos YOLO para detección de humo y fuego
#
# - Prueba iniciaal con yolov8n
# ## Salidas esperadas
#
# El entrenamiento genera:
#
# - pesos del modelo (`best.pt` y `last.pt`);
# - métricas de entrenamiento y validación;
# - curvas de desempeño;
# - matriz de confusión;
# - carpeta de resultados asociada al experimento.

# %%
# ============================================================
# Setup general del entorno
# ============================================================

from pathlib import Path
import os
import sys
import random
import shutil
import time
import yaml

SEED = 42
random.seed(SEED)

IN_COLAB = "google.colab" in sys.modules

print("Ejecutando en Google Colab:", IN_COLAB)
print("Directorio actual:", Path.cwd())
# Out:
# Ejecutando en Google Colab: True
# Directorio actual: /content

# %%
# ============================================================
# Instalación de dependencias
# ============================================================

REPO_URL = "https://github.com/Gabriela-Sol/VpC2---Deteccion-de-humo-y-fuego"
REPO_NAME = "VpC2---Deteccion-de-humo-y-fuego"

if IN_COLAB:
    # !pip install -q -r https://raw.githubusercontent.com/Gabriela-Sol/VpC2---Deteccion-de-humo-y-fuego/main/requirements.txt

print("Dependencias instaladas.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 69.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 6.5 MB/s eta 0:00:00
# Dependencias instaladas.

# %%
# ============================================================
# Verificación de GPU
# ============================================================

import torch

print("CUDA disponible:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("No se detectó GPU. Para entrenar se recomienda activar GPU en Colab.")
# Out:
# CUDA disponible: True
# GPU: Tesla T4

# %%
# ============================================================
# Montar Google Drive
# ============================================================

if IN_COLAB:
    from google.colab import drive
    drive.mount("/content/drive")

DRIVE_PROJECT_DIR = Path("/content/drive/MyDrive/VCII_DFire")
DRIVE_RUNS_DIR = DRIVE_PROJECT_DIR / "runs"
DRIVE_RUNS_DIR.mkdir(parents=True, exist_ok=True)

print("Carpeta principal en Drive:", DRIVE_PROJECT_DIR)
print("Carpeta de corridas:", DRIVE_RUNS_DIR)
# Out:
# Mounted at /content/drive
# Carpeta principal en Drive: /content/drive/MyDrive/VCII_DFire
# Carpeta de corridas: /content/drive/MyDrive/VCII_DFire/runs

# %%
# ============================================================
# Clonado o actualización del repositorio
# ============================================================

PROJECT_DIR = Path("/content") / REPO_NAME

if IN_COLAB:
    if PROJECT_DIR.exists():
        print("El repositorio ya existe. Actualizando...")
        # %cd {PROJECT_DIR}
        # !git pull
    else:
        print("Clonando repositorio...")
        # %cd /content
        # !git clone {REPO_URL}.git
        # %cd {PROJECT_DIR}
else:
    PROJECT_DIR = Path.cwd()

print("PROJECT_DIR:", PROJECT_DIR)
print("Contenido del proyecto:")
print(os.listdir(PROJECT_DIR))
# Out:
# Clonando repositorio...
# /content
# Cloning into 'VpC2---Deteccion-de-humo-y-fuego'...
# remote: Enumerating objects: 615, done.
# remote: Counting objects: 100% (615/615), done.
# remote: Compressing objects: 100% (370/370), done.
# remote: Total 615 (delta 336), reused 434 (delta 217), pack-reused 0 (from 0)
# Receiving objects: 100% (615/615), 20.63 MiB | 40.94 MiB/s, done.
# Resolving deltas: 100% (336/336), done.
# /content/VpC2---Deteccion-de-humo-y-fuego
# PROJECT_DIR: /content/VpC2---Deteccion-de-humo-y-fuego
# Contenido del proyecto:
# ['data', 'configs', 'requirements.txt', 'tests', 'pytest.ini', '.git', 'README.md', 'notebooks', 'demo', 'reports', '.gitignore', 'src']

# %%
# ============================================================
# Carga de configuración del experimento
# ============================================================

EXPERIMENT_CONFIG_PATH = PROJECT_DIR / "configs" / "experiments" / "yolov8n_baseline.yaml"

if not EXPERIMENT_CONFIG_PATH.exists():
    raise FileNotFoundError(
        f"No se encontró el archivo de configuración: {EXPERIMENT_CONFIG_PATH}"
    )

with open(EXPERIMENT_CONFIG_PATH, "r", encoding="utf-8") as file:
    experiment_config = yaml.safe_load(file)

experiment_name = experiment_config["experiment"]["name"]
model_name = experiment_config["experiment"]["model"]
family = experiment_config["experiment"]["family"]

print("Experimento:", experiment_name)
print("Familia:", family)
print("Modelo:", model_name)
print("Descripción:", experiment_config["experiment"]["description"])
print("Config path:", EXPERIMENT_CONFIG_PATH)
# Out:
# Experimento: yolov8n_baseline
# Familia: Una etapa (CNN)
# Modelo: yolov8n.pt
# Descripción: Baseline liviano con YOLOv8 nano.
# Config path: /content/VpC2---Deteccion-de-humo-y-fuego/configs/experiments/yolov8n_baseline.yaml

# %%
# ============================================================
# Descarga o localización del dataset
# ============================================================

import kagglehub

DATASET_ID = "sayedgamal99/smoke-fire-detection-yolo"

dataset_root = Path(kagglehub.dataset_download(DATASET_ID))

print("Dataset descargado/localizado en:")
print(dataset_root)

print("\nContenido del directorio raíz del dataset:")
for item in dataset_root.iterdir():
    print("-", item)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/1.archive...
# 100%|██████████| 2.84G/2.84G [00:14<00:00, 214MB/s]
# Extracting files...
# Dataset descargado/localizado en:
# /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1
#
# Contenido del directorio raíz del dataset:
# - /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data
# - /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data.yaml

# %%
# ============================================================
# Detección estructura del dataset
# ============================================================

def find_yolo_dataset_dir(root: Path) -> Path:
    """
    Busca automáticamente la carpeta que contiene la estructura esperada:
    train/images, train/labels, val/images, val/labels.
    """
    candidates = [root] + [p for p in root.rglob("*") if p.is_dir()]

    for candidate in candidates:
        train_images = candidate / "train" / "images"
        train_labels = candidate / "train" / "labels"
        val_images = candidate / "val" / "images"
        val_labels = candidate / "val" / "labels"

        if (
            train_images.exists()
            and train_labels.exists()
            and val_images.exists()
            and val_labels.exists()
        ):
            return candidate

    raise FileNotFoundError(
        "No se encontró una estructura YOLO válida con train/images, train/labels, val/images y val/labels."
    )

DATA_DIR = find_yolo_dataset_dir(dataset_root)

print("Carpeta de datos YOLO detectada:")
print(DATA_DIR)

for split in ["train", "val", "test"]:
    split_dir = DATA_DIR / split
    print(f"{split}: existe={split_dir.exists()} -> {split_dir}")
# Out:
# Carpeta de datos YOLO detectada:
# /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data
# train: existe=True -> /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/train
# val: existe=True -> /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/val
# test: existe=True -> /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test

# %%
# ============================================================
# Creación del archivo YAML para YOLO
# ============================================================

DFIRE_YAML = Path("/content/dfire_colab.yaml")

dfire_config = {
    "path": str(DATA_DIR),
    "train": "train/images",
    "val": "val/images",
    "test": "test/images",
    "nc": 2,
    "names": {
        0: "smoke",
        1: "fire",
    },
}

with open(DFIRE_YAML, "w", encoding="utf-8") as file:
    yaml.safe_dump(dfire_config, file, sort_keys=False, allow_unicode=True)

print("Archivo YAML creado en:")
print(DFIRE_YAML)

print("\nContenido:")
with open(DFIRE_YAML, "r", encoding="utf-8") as file:
    print(file.read())
# Out:
# Archivo YAML creado en:
# /content/dfire_colab.yaml
#
# Contenido:
# path: /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data
# train: train/images
# val: val/images
# test: test/images
# nc: 2
# names:
#   0: smoke
#   1: fire

# %%
# # ============================================================
# validación rápida del dataset
# ============================================================

IMAGE_EXTENSIONS = {".jpg", ".jpeg", ".png", ".bmp", ".webp"}

def count_split_files(data_dir: Path, split:str):
  images_dir = data_dir / split / "images"
  labels_dir = data_dir / split / "labels"

  image_files = [f for f in images_dir.iterdir() if f.suffix.lower() in IMAGE_EXTENSIONS]
  label_files = [f for f in labels_dir.iterdir() if f.suffix.lower() == ".txt"]

  return len(image_files), len(label_files)

for split in ["train", "val", "test"]:
  images_count, labels_count = count_split_files(DATA_DIR, split)
  print(f"{split:5s} | imágenes: {images_count:6d} | etiquetas: {labels_count:6d}")
# Out:
# train | imágenes:  14122 | etiquetas:  14122
# val   | imágenes:   3099 | etiquetas:   3099
# test  | imágenes:   4306 | etiquetas:   4306

# %%
# ============================================================
# Validación básica de etiquetas YOLO
# ============================================================

def validate_yolo_labels(labels_dir: Path):
    """
    Valida etiquetas YOLO:
    class_id x_center y_center width height
    con coordenadas normalizadas entre 0 y 1.
    """
    invalid_entries = []
    empty_files = 0
    total_boxes = 0

    for label_path in labels_dir.glob("*.txt"):
        content = label_path.read_text().strip()

        if content == "":
            empty_files += 1
            continue

        for line_number, line in enumerate(content.splitlines(), start=1):
            parts = line.split()

            if len(parts) != 5:
                invalid_entries.append((str(label_path), line_number, "Cantidad de campos != 5", line))
                continue

            try:
                class_id = int(float(parts[0]))
                coords = list(map(float, parts[1:]))
            except ValueError:
                invalid_entries.append((str(label_path), line_number, "Valores no numéricos", line))
                continue

            if class_id not in [0, 1]:
                invalid_entries.append((str(label_path), line_number, "Clase fuera de rango", line))
                continue

            if not all(0 <= value <= 1 for value in coords):
                invalid_entries.append((str(label_path), line_number, "Coordenadas fuera de [0, 1]", line))
                continue

            total_boxes += 1

    return {
        "empty_files": empty_files,
        "total_boxes": total_boxes,
        "invalid_entries": invalid_entries,
    }

for split in ["train", "val", "test"]:
    labels_dir = DATA_DIR / split / "labels"
    validation = validate_yolo_labels(labels_dir)

    print(f"\nSplit: {split}")
    print("Labels vacíos:", validation["empty_files"])
    print("Bounding boxes válidos:", validation["total_boxes"])
    print("Entradas problemáticas:", len(validation["invalid_entries"]))

    if validation["invalid_entries"][:5]:
        print("Primeras entradas problemáticas:")
        for entry in validation["invalid_entries"][:5]:
            print(entry)
# Out:
# Split: train
# Labels vacíos: 6458
# Bounding boxes válidos: 17432
# Entradas problemáticas: 0
#
# Split: val
# Labels vacíos: 1375
# Bounding boxes válidos: 3932
# Entradas problemáticas: 0
#
# Split: test
# Labels vacíos: 2005
# Bounding boxes válidos: 5185
# Entradas problemáticas: 8
# Primeras entradas problemáticas:
# ('/root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/labels/WEB10775.txt', 3, 'Coordenadas fuera de [0, 1]', '0 0.496875 0.27083333333333337 1.015625 0.5750000000000001')
# ('/root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/labels/WEB10821.txt', 3, 'Coordenadas fuera de [0, 1]', '0 0.49843750000000003 0.3388888888888889 1.0093750000000001 0.6166666666666667')
# ('/root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/labels/WEB11606.txt', 1, 'Coordenadas fuera de [0, 1]', '0 0.2578125 0.4986111111111111 0.50625 1.0027777777777778')
# ('/root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/labels/WEB11600.txt', 1, 'Coordenadas fuera de [0, 1]', '0 0.496875 0.4222222222222222 1.0562500000000001 0.8388888888888889')
# ('/root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/labels/WEB11598.txt', 1, 'Coordenadas fuera de [0, 1]', '0 0.49921875000000004 0.4013888888888889 1.0359375 0.8138888888888889')

# %%
# ============================================================
# Función de entrenamiento desde configuración
# ============================================================

from ultralytics import YOLO
import pandas as pd

def train_from_config(config: dict, data_yaml: Path) -> dict:
    """
    Entrena un modelo YOLO a partir de un archivo de configuración YAML.

    Los resultados se guardan en una carpeta específica por experimento.
    Se almacena un checkpoint por época para preservar el historial
    del entrenamiento.
    """

    exp = config["experiment"]
    train_cfg = config["training"]
    output_cfg = config["output"]

    experiment_name = exp["name"]
    model_name = exp["model"]
    project_dir = Path(output_cfg["project"])

    project_dir.mkdir(parents=True, exist_ok=True)

    print("=" * 80)
    print(f"Experimento: {experiment_name}")
    print(f"Familia: {exp['family']}")
    print(f"Modelo: {model_name}")
    print(f"Resultados en: {project_dir / experiment_name}")
    print("=" * 80)

    start_time = time.time()

    # --------------------------------------------------------
    # Modelo preentrenado
    # --------------------------------------------------------

    model = YOLO(model_name)

    # --------------------------------------------------------
    # Entrenamiento
    # --------------------------------------------------------

    results = model.train(
        data=str(data_yaml),

        epochs=train_cfg["epochs"],
        imgsz=train_cfg["imgsz"],
        batch=train_cfg["batch"],
        patience=train_cfg["patience"],

        optimizer=train_cfg["optimizer"],
        lr0=train_cfg["lr0"],

        seed=train_cfg["seed"],

        project=str(project_dir),
        name=experiment_name,

        save=True,

        # Guarda un checkpoint independiente cada epoch
        save_period=1,

        # Evita reutilizar silenciosamente una corrida anterior
        exist_ok=False,

        plots=True,
    )

    elapsed_time = time.time() - start_time

    # --------------------------------------------------------
    # Rutas de resultados
    # --------------------------------------------------------

    experiment_dir = Path(results.save_dir)

    best_model_path = experiment_dir / "weights" / "best.pt"
    last_model_path = experiment_dir / "weights" / "last.pt"
    results_csv = experiment_dir / "results.csv"

    # --------------------------------------------------------
    # Resumen del experimento
    # --------------------------------------------------------

    summary = {
        "experiment": experiment_name,
        "family": exp["family"],
        "model": model_name,

        "epochs": train_cfg["epochs"],
        "imgsz": train_cfg["imgsz"],
        "batch": train_cfg["batch"],

        "training_time_min": round(elapsed_time / 60, 2),

        "experiment_dir": str(experiment_dir),
        "best_model_path": str(best_model_path),
        "last_model_path": str(last_model_path),
        "results_csv": str(results_csv),

        "best_exists": best_model_path.exists(),
        "last_exists": last_model_path.exists(),
    }

    print("\nEntrenamiento finalizado.")
    print("Tiempo total [min]:", summary["training_time_min"])
    print("Best model:", best_model_path)
    print("Last model:", last_model_path)

    return summary
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# ============================================================
# Ejecución del experimento baseline
# ============================================================

RUN_TRAINING = False

if RUN_TRAINING:
    experiment_summary = train_from_config(
        config=experiment_config,
        data_yaml=DFIRE_YAML,
    )

    summary_df = pd.DataFrame([experiment_summary])
    display(summary_df)
else:
  # resume training
  model = YOLO("/content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline-2/weights/last.pt")

  results = model.train(resume=True)
# Out:
# WARNING ⚠️ model '/content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline-2/weights/last.pt' is not a resumable training checkpoint (missing epoch/optimizer state). Use 'resume' only to continue incomplete training. Starting new training instead.
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco8.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline-2/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/VpC2---Deteccion-de-humo-y-fuego/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
# WARNING ⚠️ Dataset 'coco8.yaml' images not found, missing path '/content/VpC2---Deteccion-de-humo-y-fuego/datasets/coco8/images/val'
# Downloading https://ultralytics.com/assets/coco8.zip to '/content/VpC2---Deteccion-de-humo-y-fuego/datasets/coco8.zip': 100% ━━━━━━━━━━━━ 432.8KB 9.2MB/s 0.0s
# Unzipping /content/VpC2---Deteccion-de-humo-y-fuego/datasets/coco8.zip to /content/VpC2---Deteccion-de-humo-y-fuego/datasets/coco8...: 100% ━━━━━━━━━━━━ 25/25 3.8Kfiles/s 0.0s
# Dataset download success ✅ (0.2s), saved to /content/VpC2---Deteccion-de-humo-y-fuego/datasets
#
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 14.9MB/s 0.0s
# Overriding model.yaml nc=2 with nc=80
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    897664  ultralytics.nn.modules.head.Detect           [80, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,157,200 parameters, 3,157,184 gradients, 8.9 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 19.4MB/s 0.3s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1287.2±1044.1 MB/s, size: 50.0 KB)
# train: Scanning /content/VpC2---Deteccion-de-humo-y-fuego/datasets/coco8/labels/train... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 1.3Kit/s 0.0s
# train: New cache created: /content/VpC2---Deteccion-de-humo-y-fuego/datasets/coco8/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1690.5±451.6 MB/s, size: 54.0 KB)
# val: Scanning /content/VpC2---Deteccion-de-humo-y-fuego/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 1.5Kit/s 0.0s
# val: New cache created: /content/VpC2---Deteccion-de-humo-y-fuego/datasets/coco8/labels/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /content/VpC2---Deteccion-de-humo-y-fuego/runs/detect/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /content/VpC2---Deteccion-de-humo-y-fuego/runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100     0.598G      1.873      5.173      2.348         31        640: 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.5it/s 0.2s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100       0.6G      1.878      5.223      2.056         25        640: 100% ━━━━━━━━━━━━ 1/1 8.5it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 16.1it/s 0.1s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100     0.609G      2.106      5.642      2.129         12        640: 100% ━━━━━━━━━━━━ 1/1 8.5it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 18.0it/s 0.1s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100     0.609G       2.14      5.092       2.14         39        640: 100% ━━━━━━━━━━━━ 1/1 8.2it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.6it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100     0.609G       2.38      5.198      2.195         47        640: 100% ━━━━━━━━━━━━ 1/1 8.7it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 25.3it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100     0.609G      1.936      5.263      2.176         19        640: 100% ━━━━━━━━━━━━ 1/1 9.1it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 23.9it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100     0.609G      2.101      5.268      2.043         25        640: 100% ━━━━━━━━━━━━ 1/1 4.5it/s 0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 23.3it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100     0.619G      1.632      5.191      1.966         24        640: 100% ━━━━━━━━━━━━ 1/1 9.1it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 25.2it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100     0.631G      1.599      4.889      1.862         27        640: 100% ━━━━━━━━━━━━ 1/1 9.0it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 21.6it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100     0.631G      1.871      5.234      1.943         18        640: 100% ━━━━━━━━━━━━ 1/1 8.3it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 25.2it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100     0.631G      1.844      5.065      2.058         38        640: 100% ━━━━━━━━━━━━ 1/1 3.7it/s 0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.5it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100     0.631G      1.896       5.07      2.178         31        640: 100% ━━━━━━━━━━━━ 1/1 8.0it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.7it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100     0.631G      1.793      5.165      2.139         27        640: 100% ━━━━━━━━━━━━ 1/1 7.4it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.6it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100     0.631G      2.027      5.167      2.026         28        640: 100% ━━━━━━━━━━━━ 1/1 8.3it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.5it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100     0.631G      2.185      5.207      2.152         29        640: 100% ━━━━━━━━━━━━ 1/1 8.3it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.0it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100     0.631G      1.794      5.274      1.979         20        640: 100% ━━━━━━━━━━━━ 1/1 8.1it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 24.5it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100     0.631G      1.824      5.179       2.18         14        640: 100% ━━━━━━━━━━━━ 1/1 9.2it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 25.4it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100     0.631G      1.562      4.834      1.991         32        640: 100% ━━━━━━━━━━━━ 1/1 9.3it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 25.3it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100     0.631G       1.77      5.154       2.05         25        640: 100% ━━━━━━━━━━━━ 1/1 8.2it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 25.5it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100     0.631G      1.758      4.991      1.962         40        640: 100% ━━━━━━━━━━━━ 1/1 9.2it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 24.2it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100     0.631G      1.849      4.959      2.039         20        640: 100% ━━━━━━━━━━━━ 1/1 9.0it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 24.0it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100     0.631G      1.768      4.938      1.916         40        640: 100% ━━━━━━━━━━━━ 1/1 8.1it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 23.6it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100     0.631G      2.123      5.132      1.977         41        640: 100% ━━━━━━━━━━━━ 1/1 8.5it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 23.1it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100     0.631G      1.773       4.94      1.929         22        640: 100% ━━━━━━━━━━━━ 1/1 8.9it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 24.0it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100     0.631G      2.029      5.047      2.438         10        640: 100% ━━━━━━━━━━━━ 1/1 8.5it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 24.8it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100     0.631G      1.778      4.967      1.861         38        640: 100% ━━━━━━━━━━━━ 1/1 8.7it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 25.6it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100     0.631G      2.088      4.997      2.532         30        640: 100% ━━━━━━━━━━━━ 1/1 8.5it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 22.3it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100     0.631G      1.881      4.958      1.984         25        640: 100% ━━━━━━━━━━━━ 1/1 7.7it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 21.4it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100     0.631G      1.888      4.855      1.879         35        640: 100% ━━━━━━━━━━━━ 1/1 8.6it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 23.7it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100     0.631G      1.919      4.976       1.97         43        640: 100% ━━━━━━━━━━━━ 1/1 8.1it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 24.0it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100     0.631G      1.675       4.81      1.772         34        640: 100% ━━━━━━━━━━━━ 1/1 8.3it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 25.6it/s 0.0s
#                    all          4         17          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100     0
640: 100% ━━━━━━━━━━━━ 1/1 9.0it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 23.2it/s 0.0s
#                    all          4         17          0          0          0          0
#
# 100 epochs completed in 0.013 hours.
# Optimizer stripped from /content/VpC2---Deteccion-de-humo-y-fuego/runs/detect/train/weights/last.pt, 6.5MB
# Optimizer stripped from /content/VpC2---Deteccion-de-humo-y-fuego/runs/detect/train/weights/best.pt, 6.5MB
#
# Validating /content/VpC2---Deteccion-de-humo-y-fuego/runs/detect/train/weights/best.pt...
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 26.4it/s 0.0s
#                    all          4         17          0          0          0          0
#                 person          3         10          0          0          0          0
#                    dog          1          1          0          0          0          0
#                  horse          1          2          0          0          0          0
#               elephant          1          2          0          0          0          0
#               umbrella          1          1          0          0          0          0
#           potted plant          1          1          0          0          0          0
# Speed: 0.2ms preprocess, 3.5ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /content/VpC2---Deteccion-de-humo-y-fuego/runs/detect/train

# %%
# ============================================================
# Verificación de pesos guardados
# ============================================================

experiment_name = experiment_config["experiment"]["name"]
project_dir = Path(experiment_config["output"]["project"])
experiment_dir = project_dir / experiment_name

best_model_path = experiment_dir / "weights" / "best.pt"
last_model_path = experiment_dir / "weights" / "last.pt"

print("Carpeta del experimento:", experiment_dir)
print("Best model existe:", best_model_path.exists(), best_model_path)
print("Last model existe:", last_model_path.exists(), last_model_path)
# Out:
# Carpeta del experimento: /content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline
# Best model existe: True /content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline/weights/best.pt
# Last model existe: True /content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline/weights/last.pt

# %%
# ============================================================
# Guardar resumen general de experimentos
# ============================================================

SUMMARY_PATH = DRIVE_PROJECT_DIR / "experiment_summary.csv"

if RUN_TRAINING:
    if SUMMARY_PATH.exists():
        previous_summary = pd.read_csv(SUMMARY_PATH)
        updated_summary = pd.concat(
            [previous_summary, summary_df],
            ignore_index=True
        )
    else:
        updated_summary = summary_df.copy()

    updated_summary.to_csv(SUMMARY_PATH, index=False)
    display(updated_summary)

    print("Resumen actualizado en:", SUMMARY_PATH)
else:
    print("No se actualizó el resumen porque no se entrenó.")
# Out:
# No se actualizó el resumen porque no se entrenó.

# %%
# ============================================================
# Copiar resultados principales al repositorio local
# ============================================================

REPORTS_RESULTS_DIR = PROJECT_DIR / "reports" / "results" / experiment_name
REPORTS_RESULTS_DIR.mkdir(parents=True, exist_ok=True)

files_to_copy = [
    "results.csv",
    "results.png",
    "confusion_matrix.png",
    "confusion_matrix_normalized.png",
    "PR_curve.png",
    "F1_curve.png",
    "P_curve.png",
    "R_curve.png",
]

for filename in files_to_copy:
    src = experiment_dir / filename
    dst = REPORTS_RESULTS_DIR / filename

    if src.exists():
        shutil.copy(src, dst)
        print("Copiado:", dst)
    else:
        print("No encontrado:", src)

# Guardar también la configuración usada para este experimento
used_config_path = REPORTS_RESULTS_DIR / "experiment_config_used.yaml"

with open(used_config_path, "w", encoding="utf-8") as file:
    yaml.safe_dump(experiment_config, file, sort_keys=False, allow_unicode=True)

print("Config usada guardada en:", used_config_path)
# Out:
# Copiado: /content/VpC2---Deteccion-de-humo-y-fuego/reports/results/yolov8n_baseline/results.csv
# Copiado: /content/VpC2---Deteccion-de-humo-y-fuego/reports/results/yolov8n_baseline/results.png
# Copiado: /content/VpC2---Deteccion-de-humo-y-fuego/reports/results/yolov8n_baseline/confusion_matrix.png
# Copiado: /content/VpC2---Deteccion-de-humo-y-fuego/reports/results/yolov8n_baseline/confusion_matrix_normalized.png
# No encontrado: /content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline/PR_curve.png
# No encontrado: /content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline/F1_curve.png
# No encontrado: /content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline/P_curve.png
# No encontrado: /content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline/R_curve.png
# Config usada guardada en: /content/VpC2---Deteccion-de-humo-y-fuego/reports/results/yolov8n_baseline/experiment_config_used.yaml

# %%
# ============================================================
# Commit y push seguro de resultados al repositorio real de GitHub
# ============================================================

from getpass import getpass
import subprocess
from pathlib import Path

# %cd {PROJECT_DIR}

# ------------------------------------------------------------
# Configuración de usuario para el commit
# ------------------------------------------------------------

# !git config user.name "Gabriela-Sol"
# !git config user.email "solgab.salazar@gmail.com"

print("Estado inicial:")
# !git status -sb

# ------------------------------------------------------------
# Traer cambios remotos antes de pushear
# ------------------------------------------------------------

print("\nActualizando rama local con cambios remotos...")
pull_result = subprocess.run(
    ["git", "pull", "--rebase", "origin", "main"],
    text=True,
    capture_output=True,
)

print(pull_result.stdout)
print(pull_result.stderr)

if pull_result.returncode != 0:
    print("Hubo un problema durante el pull --rebase.")
    print("Revisar si hay conflictos antes de continuar.")
    raise RuntimeError("No se pudo completar git pull --rebase.")

print("\nEstado después del pull --rebase:")
# !git status -sb

# ------------------------------------------------------------
# Agregar archivos del experimento
# ------------------------------------------------------------

paths_to_add = [
    f"reports/results/{experiment_name}/",
    "configs/experiments/yolov8n_baseline.yaml",
]

print("\nAgregando archivos al commit:")

for path in paths_to_add:
    if Path(path).exists():
        subprocess.run(["git", "add", path], check=True)
        print("Agregado:", path)
    else:
        print("No existe, se omite:", path)

print("\nEstado después de git add:")
status_result = subprocess.run(
    ["git", "status", "--short"],
    text=True,
    capture_output=True,
)

print(status_result.stdout)

# ------------------------------------------------------------
# Commit solo si hay cambios
# ------------------------------------------------------------

if not status_result.stdout.strip():
    print("No hay cambios nuevos para commitear.")
else:
    commit_message = f"results: update {experiment_name} outputs"

    commit_result = subprocess.run(
        ["git", "commit", "-m", commit_message],
        text=True,
        capture_output=True,
    )

    print("\nSalida del commit:")
    print(commit_result.stdout)
    print(commit_result.stderr)

    if commit_result.returncode != 0:
        print("No se pudo crear el commit.")
        raise RuntimeError("Error en git commit.")

# ------------------------------------------------------------
# Push seguro con token
# ------------------------------------------------------------

print("\nEstado antes del push:")
# !git status -sb

github_token = getpass("Pegá tu GitHub token: ")

repo_url = (
    f"https://x-access-token:{github_token}"
    "@github.com/Gabriela-Sol/VpC2---Deteccion-de-humo-y-fuego.git"
)

push_result = subprocess.run(
    ["git", "push", repo_url, "HEAD:main"],
    text=True,
    capture_output=True,
)

def sanitize(text):
    if github_token:
        return text.replace(github_token, "***TOKEN***")
    return text

print("\nReturn code push:", push_result.returncode)

if push_result.returncode == 0:
    print("Push realizado correctamente.")
else:
    print("Error en el push:")
    print(sanitize(push_result.stdout))
    print(sanitize(push_result.stderr))

github_token = None
repo_url = None

print("\nEstado final:")
# !git status -sb
# Out:
# /content/VpC2---Deteccion-de-humo-y-fuego
# Estado inicial:
# ## main...origin/main
#  M reports/results/yolov8n_baseline/experiment_config_used.yaml
#  M reports/results/yolov8n_baseline/results.csv
# ?? datasets/
#
# Actualizando rama local con cambios remotos...
#
# error: cannot pull with rebase: You have unstaged changes.
# error: please commit or stash them.
#
# Hubo un problema durante el pull --rebase.
# Revisar si hay conflictos antes de continuar.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_2613/1855475807.py in <cell line: 0>()
#      36     print("Hubo un problema durante el pull --rebase.")
#      37     print("Revisar si hay conflictos antes de continuar.")
# ---> 38     raise RuntimeError("No se pudo completar git pull --rebase.")
#      39
#      40 print("\nEstado después del pull --rebase:")
#
# RuntimeError: No se pudo completar git pull --rebase.

# %%
from ultralytics import YOLO
from pathlib import Path

# Ruta al best.pt (ajustá según dónde quedó guardado)
MODEL_PATH = Path("/content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline-2/weights/best.pt")
# o si estás corriendo local: experiment_dir / "weights" / "best.pt"

model = YOLO(str(MODEL_PATH))

# %%
metrics = model.val(data="/content/dfire_colab.yaml")  # mismo yaml usado en el entrenamiento
print(metrics.box.map)     # mAP50-95
print(metrics.box.map50)   # mAP50
print(metrics.box.map75)   # mAP75
# Out:
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3473.4±1365.5 MB/s, size: 222.5 KB)
# val: Scanning /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/val/labels... 3099 images, 1375 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3099/3099 1.4Kit/s 2.2s
# val: /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/val/images/WEB07535.jpg: corrupt JPEG restored and saved
# val: /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/val/images/WEB07536.jpg: corrupt JPEG restored and saved
# val: /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/val/images/WEB07539.jpg: corrupt JPEG restored and saved
# val: /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/val/images/WEB07542.jpg: corrupt JPEG restored and saved
# val: /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/val/images/WEB07561.jpg: corrupt JPEG restored and saved
# val: New cache created: /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/val/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 194/194 12.4it/s 15.6s
#                    all       3099       3932       0.78      0.691      0.771      0.447
#                  smoke       1550       1756      0.819      0.751      0.824      0.514
#                   fire        879       2176       0.74      0.631      0.717       0.38
# Speed: 0.5ms preprocess, 2.2ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /content/VpC2---Deteccion-de-humo-y-fuego/runs/detect/val
# 0.44706871840432694
# 0.770707662861277
# 0.454022060546335

# %%
# ============================================================
# Predicciones sobre el conjunto de test
# ============================================================

TEST_IMAGES_DIR = DATA_DIR / "test" / "images"

print("Directorio de test:")
print(TEST_IMAGES_DIR)

print("Existe:", TEST_IMAGES_DIR.exists())
# Out:
# Directorio de test:
# /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images
# Existe: True

# %%
results = model.predict(
    source=str(TEST_IMAGES_DIR),
    save=True,
    conf=0.25
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06723.jpg: 384x640 (no detections), 5.7ms
# image 2/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06724.jpg: 352x640 (no detections), 39.4ms
# image 3/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06725.jpg: 384x640 (no detections), 6.3ms
# image 4/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06726.jpg: 384x640 (no detections), 7.7ms
# image 5/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06727.jpg: 384x640 (no detections), 5.9ms
# image 6/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06728.jpg: 384x640 (no detections), 5.6ms
# image 7/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06729.jpg: 384x640 (no detections), 5.8ms
# image 8/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06730.jpg: 384x640 (no detections), 5.7ms
# image 9/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06731.jpg: 384x640 (no detections), 5.4ms
# image 10/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06732.jpg: 384x640 (no detections), 6.4ms
# image 11/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06733.jpg: 384x640 (no detections), 5.4ms
# image 12/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06734.jpg: 384x640 (no detections), 5.6ms
# image 13/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06735.jpg: 384x640 1 smoke, 5.5ms
# image 14/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06736.jpg: 384x640 (no detections), 6.1ms
# image 15/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06737.jpg: 384x640 (no detections), 6.1ms
# image 16/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06738.jpg: 384x640 (no detections), 5.5ms
# image 17/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06739.jpg: 384x640 (no detections), 5.7ms
# image 18/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06740.jpg: 384x640 (no detections), 5.5ms
# image 19/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF06741.jpg: 384x640 (no detections), 5.7ms
# image 20/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/AoF
4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11768.jpg: 352x640 (no detections), 6.2ms
# image 4269/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11769.jpg: 352x640 1 smoke, 8.4ms
# image 4270/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11770.jpg: 448x640 1 smoke, 1 fire, 7.6ms
# image 4271/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11771.jpg: 480x640 1 smoke, 6.6ms
# image 4272/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11772.jpg: 480x640 2 smokes, 6.0ms
# image 4273/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11773.jpg: 480x640 1 smoke, 5.8ms
# image 4274/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11774.jpg: 480x640 1 smoke, 6.2ms
# image 4275/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11775.jpg: 640x640 1 smoke, 1 fire, 7.9ms
# image 4276/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11776.jpg: 352x640 1 smoke, 6.4ms
# image 4277/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11777.jpg: 384x640 1 smoke, 1 fire, 6.7ms
# image 4278/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11778.jpg: 384x640 1 smoke, 5.9ms
# image 4279/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11779.jpg: 384x640 1 smoke, 6.2ms
# image 4280/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11780.jpg: 384x640 1 smoke, 6.3ms
# image 4281/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11781.jpg: 448x640 1 smoke, 6.4ms
# image 4282/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11782.jpg: 384x640 1 smoke, 3 fires, 6.9ms
# image 4283/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11783.jpg: 384x640 2 smokes, 5.9ms
# image 4284/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11784.jpg: 512x640 (no detections), 6.4ms
# image 4285/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11785.jpg: 480x640 2 smokes, 6.5ms
# image 4286/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11786.jpg: 352x640 1 smoke, 6.3ms
# image 4287/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11787.jpg: 352x640 1 smoke, 6.0ms
# image 4288/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11788.jpg: 640x384 1 smoke, 6.9ms
# image 4289/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11789.jpg: 416x640 1 smoke, 6.3ms
# image 4290/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11790.jpg: 384x640 1 smoke, 6.1ms
# image 4291/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11791.jpg: 384x640 1 smoke, 6.0ms
# image 4292/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11792.jpg: 384x640 1 smoke, 5.6ms
# image 4293/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11793.jpg: 384x640 1 smoke, 5.5ms
# image 4294/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11794.jpg: 384x640 1 smoke, 6.4ms
# image 4295/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11795.jpg: 384x640 1 smoke, 5.9ms
# image 4296/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11796.jpg: 384x640 1 smoke, 5.6ms
# image 4297/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11797.jpg: 480x640 1 smoke, 1 fire, 6.7ms
# image 4298/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11798.jpg: 384x640 1 smoke, 6.5ms
# image 4299/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11799.jpg: 448x640 1 smoke, 2 fires, 6.5ms
# image 4300/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11800.jpg: 384x640 2 smokes, 7.6ms
# image 4301/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11801.jpg: 480x640 1 smoke, 7.3ms
# image 4302/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11802.jpg: 448x640 1 smoke, 2 fires, 6.5ms
# image 4303/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11803.jpg: 384x640 2 smokes, 4 fires, 7.7ms
# image 4304/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11804.jpg: 480x640 1 smoke, 6.8ms
# image 4305/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11805.jpg: 320x640 1 smoke, 2 fires, 6.5ms
# image 4306/4306 /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/test/images/WEB11806.jpg: 384x640 1 smoke, 6.3ms
# Speed: 1.6ms preprocess, 6.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/VpC2---Deteccion-de-humo-y-fuego/runs/detect/predict

# %%
from PIL import Image

experiment_dir = Path("/content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline-2")

Image.open(experiment_dir / "results.png")               # curvas de loss/mAP durante entrenamiento
Image.open(experiment_dir / "confusion_matrix.png")       # matriz de confusión
Image.open(experiment_dir / "confusion_matrix_normalized.png")
# Image.open(experiment_dir / "PR_curve.png")
# Image.open(experiment_dir / "F1_curve.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2250>

# %%
import pandas as pd
df = pd.read_csv(experiment_dir / "results.csv")
df.tail()
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 45     46  2680.92         1.25046         0.87389         1.24777
# 46     47  2964.47         1.24783         0.87255         1.24198
# 47     48  3261.24         1.23646         0.85473         1.23754
# 48     49  3553.50         1.22687         0.83608         1.22881
# 49     50  3848.34         1.22012         0.83325         1.22646
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 45               0.77710            0.68557           0.76698
# 46               0.77095            0.69595           0.76913
# 47               0.78092            0.68704           0.76984
# 48               0.78605            0.68690           0.77054
# 49               0.77800            0.69305           0.77054
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 45              0.44434       1.25594       1.08355       1.19920  0.003270
# 46              0.44618       1.25815       1.07324       1.19720  0.002676
# 47              0.44561       1.25862       1.06088       1.19859  0.002082
# 48              0.44627       1.26016       1.04724       1.20183  0.001488
# 49              0.44699       1.26012       1.04091       1.20209  0.000894
#
#       lr/pg1    lr/pg2    lr/pg3    lr/pg4    lr/pg5    lr/pg6    lr/pg7
# 45  0.001090  0.003270  0.001090  0.003270  0.001090  0.003270  0.001090
# 46  0.000892  0.002676  0.000892  0.002676  0.000892  0.002676  0.000892
# 47  0.000694  0.002082  0.000694  0.002082  0.000694  0.002082  0.000694
# 48  0.000496  0.001488  0.000496  0.001488  0.000496  0.001488  0.000496
# 49  0.000298  0.000894  0.000298  0.000894  0.000298  0.000894  0.000298

# %%
from ultralytics import YOLO

MODEL_PATH = "/content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline-2/weights/best.pt"
model = YOLO(MODEL_PATH)

metrics = model.val(
    data="/content/dfire_colab.yaml",
    split="val",
    plots=True,
    project="/content/drive/MyDrive/VCII_DFire/runs",
    name="yolov8n_baseline_val-2",
)

print("Carpeta de resultados:", metrics.save_dir)
# Out:
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2069.8±1404.7 MB/s, size: 141.7 KB)
# val: Scanning /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/val/labels.cache... 3099 images, 1375 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3099/3099 764.6Mit/s 0.0s
# val: /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/val/images/WEB07535.jpg: corrupt JPEG restored and saved
# val: /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/val/images/WEB07536.jpg: corrupt JPEG restored and saved
# val: /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/val/images/WEB07539.jpg: corrupt JPEG restored and saved
# val: /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/val/images/WEB07542.jpg: corrupt JPEG restored and saved
# val: /root/.cache/kagglehub/datasets/sayedgamal99/smoke-fire-detection-yolo/versions/1/data/val/images/WEB07561.jpg: corrupt JPEG restored and saved
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 194/194 12.6it/s 15.4s
#                    all       3099       3932       0.78      0.691      0.771      0.447
#                  smoke       1550       1756      0.819      0.751      0.824      0.514
#                   fire        879       2176       0.74      0.631      0.717       0.38
# Speed: 0.5ms preprocess, 2.1ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline_val-2-2
# Carpeta de resultados: /content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline_val-2-2

# %%
from pathlib import Path
from IPython.display import Image, display

experiment_dir = Path("/content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline_val-2-2")

for img_name in [
    "results.png",              # curvas de loss y métricas por época
    "confusion_matrix.png",
    "confusion_matrix_normalized.png",
    "PR_curve.png",
    "F1_curve.png",
    "P_curve.png",
    "R_curve.png",
]:
    img_path = experiment_dir / img_name
    if img_path.exists():
        print(img_name)
        display(Image(filename=str(img_path)))
    else:
        print("No encontrado:", img_path)
# Out:
# No encontrado: /content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline_val-2-2/results.png
# confusion_matrix.png
# confusion_matrix_normalized.png
# No encontrado: /content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline_val-2-2/PR_curve.png
# No encontrado: /content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline_val-2-2/F1_curve.png
# No encontrado: /content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline_val-2-2/P_curve.png
# No encontrado: /content/drive/MyDrive/VCII_DFire/runs/yolov8n_baseline_val-2-2/R_curve.png
